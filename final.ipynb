# %%
import csv

file2=open('globalterrorism.csv',"r")  #open file
# Form a dictionary with column that we want to extract as keys
reader = csv.DictReader(file2)
data = {}
for row in reader:
    for header, value in row.items():
        try:
            data[header].append(value)          #appending values in colums we wat to extract
        except KeyError:
            data[header] = [value]

                        #form a list  of row values

y1=data["targtype1_txt"],data["motive"],data["target1"],data["gname"],data["addnotes"],data['summary']


for row in y1:
    #print (row)

f = open('final.txt', 'w')
s = str(row)
f.write(s)
f.close

y1
# Out:
# (['Private Citizens & Property',
#   'Government (Diplomatic)',
#   'Journalists & Media',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Police',
#   'Police',
#   'Utilities',
#   'Military',
#   'Government (General)',
#   'Military',
#   'Military',
#   'Airports & Aircraft',
#   'Government (General)',
#   'Business',
#   'Government (General)',
#   'Military',
#   'Educational Institution',
#   'Business',
#   'Business',
#   'Police',
#   'Educational Institution',
#   'Educational Institution',
#   'Military',
#   'Violent Political Party',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Business',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Police',
#   'Government (General)',
#   'Police',
#   'Government (General)',
#   'Police',
#   'Religious Figures/Institutions',
#   'Unknown',
#   'Business',
#   'Military',
#   'Military',
#   'Police',
#   'Government (General)',
#   'Police',
#   'Business',
#   'Business',
#   'Business',
#   'Private Citizens & Property',
#   'Transportation',
#   'Government (General)',
#   'Religious Figures/Institutions',
#   'Government (General)',
#   'Utilities',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Business',
#   'Business',
#   'Business',
#   'Private Citizens & Property',
#   'Airports & Aircraft',
#   'Educational Institution',
#   'Police',
#   'Private Citizens & Property',
#   'Police',
#   'Business',
#   'Military',
#   'Police',
#   'Business',
#   'Business',
#   'Police',
#   'Business',
#   'Utilities',
#   'Educational Institution',
#   'Military',
#   'Police',
#   'Police',
#   'Government (General)',
#   'Educational Institution',
#   'Educational Institution',
#   'Airports & Aircraft',
#   'Airports & Aircraft',
#   'Police',
#   'Military',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Educational Institution',
#   'Utilities',
#   'Utilities',
#   'Utilities',
#   'Utilities',
#   'Utilities',
#   'Military',
#   'Private Citizens & Property',
#   'Military',
#   'Educational Institution',
#   'Tourists',
#   'Government (Diplomatic)',
#   'Airports & Aircraft',
#   'Military',
#   'Military',
#   'Police',
#   'Police',
#   'Private Citizens & Property',
#   'Government (General)',
#   'Private Citizens & Property',
#   'Government (General)',
#   'Military',
#   'Transportation',
#   'Private Citizens & Property',
#   'Government (General)',
#   'Private Citizens & Property',
#   'Military',
#   'Government (Diplomatic)',
#   'Police',
#   'Police',
#   'Educational Institution',
#   'Private Citizens & Property',
#   'Religious Figures/Institutions',
#   'Military',
#   'Unknown',
#   'Government (General)',
#   'Government (General)',
#   'Business',
#   'Government (Diplomatic)',
#   'Military',
#   'Business',
#   'Business',
#   'Police',
#   'Police',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Journalists & Media',
#   'Airports & Aircraft',
#   'Military',
#   'Military',
#   'Business',
#   'Police',
#   'Government (General)',
#   'Educational Institution',
#   'Utilities',
#   'Military',
#   'Private Citizens & Property',
#   'Government (General)',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Private Citizens & Property',
#   'Military',
#   'Military',
#   'Government (Diplomatic)',
#   'Business',
#   'Private Citizens & Property',
#   'Police',
#   'Police',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Military',
#   'Government (Diplomatic)',
#   'Airports & Aircraft',
#   'Government (General)',
#   'Educational Institution',
#   'Government (Diplomatic)',
#   'Educational Institution',
#   'Educational Institution',
#   'Military',
#   'Military',
#   'Business',
#   'Business',
#   'Business',
#   'Private Citizens & Property',
#   'Educational Institution',
#   'Government (Diplomatic)',
#   'Military',
#   'Utilities',
#   'Business',
#   'NGO',
#   'Educational Institution',
#   'Business',
#   'Private Citizens & Property',
#   'Educational Institution',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Business',
#   'Utilities',
#   'Educational Institution',
#   'Religious Figures/Institutions',
#   'Police',
#   'Business',
#   'Educational Institution',
#   'Business',
#   'Government (Diplomatic)',
#   'Private Citizens & Property',
#   'Educational Institution',
#   'Educational Institution',
#   'Business',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Business',
#   'Police',
#   'Religious Figures/Institutions',
#   'Business',
#   'Business',
#   'Government (General)',
#   'Police',
#   'Educational Institution',
#   'Airports & Aircraft',
#   'Business',
#   'Business',
#   'Educational Institution',
#   'Educational Institution',
#   'Government (General)',
#   'Police',
#   'Educational Institution',
#   'Military',
#   'Telecommunication',
#   'Telecommunication',
#   'Police',
#   'Educational Institution',
#   'Police',
#   'Military',
#   'Government (Diplomatic)',
#   'Airports & Aircraft',
#   'Educational Institution',
#   'Business',
#   'Business',
#   'Business',
#   'Government (General)',
#   'Food or Water Supply',
#   'Government (General)',
#   'Business',
#   'Educational Institution',
#   'Educational Institution',
#   'Educational Institution',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Business',
#   'Government (General)',
#   'Police',
#   'Business',
#   'Religious Figures/Institutions',
#   'Business',
#   'Military',
#   'Military',
#   'Educational Institution',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Military',
#   'Government (General)',
#   'Military',
#   'Government (Diplomatic)',
#   'Military',
#   'Educational Institution',
#   'Government (General)',
#   'Business',
#   'Government (General)',
#   'Military',
#   'Military',
#   'Government (General)',
#   'Military',
#   'Government (General)',
#   'Religious Figures/Institutions',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Government (General)',
#   'Police',
#   'Business',
#   'NGO',
#   'Airports & Aircraft',
#   'Telecommunication',
#   'Government (General)',
#   'Police',
#   'Military',
#   'Private Citizens & Property',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Educational Institution',
#   'Business',
#   'Business',
#   'Military',
#   'Business',
#   'Business',
#   'Military',
#   'Government (General)',
#   'Utilities',
#   'Government (General)',
#   'Educational Institution',
#   'Private Citizens & Property',
#   'Terrorists/Non-State Militia',
#   'Police',
#   'Police',
#   'Business',
#   'Business',
#   'Business',
#   'Government (General)',
#   'Religious Figures/Institutions',
#   'Religious Figures/Institutions',
#   'Police',
#   'Government (General)',
#   'Educational Institution',
#   'Educational Institution',
#   'Government (General)',
#   'Military',
#   'Private Citizens & Property',
#   'Military',
#   'Business',
#   'Government (General)',
#   'Airports & Aircraft',
#   'Utilities',
#   'Private Citizens & Property',
#   'Government (General)',
#   'Police',
#   'Military',
#   'Government (Diplomatic)',
#   'Business',
#   'Government (General)',
#   'Business',
#   'Police',
#   'Military',
#   'Government (Diplomatic)',
#   'Police',
#   'Government (General)',
#   'Military',
#   'Business',
#   'Airports & Aircraft',
#   'Police',
#   'Business',
#   'Business',
#   'Government (General)',
#   'Private Citizens & Property',
#   'Military',
#   'Government (Diplomatic)',
#   'Airports & Aircraft',
#   'Police',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Police',
#   'Business',
#   'Business',
#   'Government (General)',
#   'Government (General)',
#   'Police',
#   'Police',
#   'Educational Institution',
#   'Other',
#   'Business',
#   'Business',
#   'Police',
#   'Police',
#   'Police',
#   'Government (General)',
#   'Military',
#   'Business',
#   'Private Citizens & Property',
#   'Terrorists/Non-State Militia',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Religious Figures/Institutions',
#   'Police',
#   'Educational Institution',
#   'Business',
#   'Police',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Religious Figures/Institutions',
#   'Airports & Aircraft',
#   'Private Citizens & Property',
#   'Educational Institution',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Business',
#   'Police',
#   'Private Citizens & Property',
#   'Business',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Police',
#   'Private Citizens & Property',
#   'Government (Diplomatic)',
#   'Business',
#   'Government (Diplomatic)',
#   'Business',
#   'Journalists & Media',
#   'Government (General)',
#   'Government (General)',
#   'Government (General)',
#   'Business',
#   'Private Citizens & Property',
#   'Business',
#   'NGO',
#   'Military',
#   'NGO',
#   'Military',
#   'Government (General)',
#   'Police',
#   'Business',
#   'NGO',
#   'Business',
#   'Business',
#   'Police',
#   'Business',
#   'Airports & Aircraft',
#   'Utilities',
#   'Military',
#   'Business',
#   'Government (General)',
#   'Government (Diplomatic)',
#   'NGO',
#   'Business',
#   'Military',
#   'Business',
#   'Utilities',
#   'Telecommunication',
#   'Military',
#   'Military',
#   'Government (General)',
#   'Business',
#   'Journalists & Media',
#   'Government (General)',
#   'Utilities',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Government (Diplomatic)',
#   'Business',
#   'Government (Diplomatic)',
#   'Police',
#   'Business',
#   'Police',
#   'Business',
#   'Police',
#   'Government (General)',
#   'Government (General)',
#   'Government (General)',
#   'Business',
#   'Government (General)',
#   'Police',
#   'Police',
#   'Police',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Military',
#   'NGO',
#   'Government (General)',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Police',
#   'Telecommunication',
#   'Educational Institution',
#   'Police',
#   'Military',
#   'Military',
#   'Government (Diplomatic)',
#   'Police',
#   'Business',
#   'Educational Institution',
#   'Educational Institution',
#   'Military',
#   'Government (Diplomatic)',
#   'Business',
#   'Government (General)',
#   'Government (General)',
#   'Government (Diplomatic)',
#   'Educational Institution',
#   'Military',
#   'Military',
#   'Business',
#   'Business',
#   'Government (Diplomatic)',
#   'Police',
#   'Business',
#   'Business',
#   'Private Citizens & Property',
#   'Business',
#   'Government (General)',
#   'Terrorists/Non-State Militia',
#   'Business',
#   'Government (General)',
#   'Police',
#   'Government (General)',
#   'Airports & Aircraft',
#   'Airports & Aircraft',
#   'Airports & Aircraft',
#   'Airports & Aircraft',
#   'Police',
#   'Private Citizens & Property',
#   'Government (Diplomatic)',
#   'Journalists & Media',
#   'Educational Institution',
#   'Government (Diplomatic)',
#   'Business',
#   'Journalists & Media',
#   'Government (Diplomatic)',
#   'Business',
#   'Business',
#   'Police',
#   'Police',
#   'Military',
#   'Police',
#   'Business',
#   'Government (General)',
#   'Government (Diplomatic)',
#   'Military',
#   'Police',
#   'Government (Diplomatic)',
#   'Airports & Aircraft',
#   'Private Citizens & Property',
#   'Business',
#   'Private Citizens & Property',
#   'Military',
#   'Educational Institution',
#   'Food or Water Supply',
#   'Government (Diplomatic)',
#   'Business',
#   'Government (General)',
#   'Private Citizens & Property',
#   'Educational Institution',
#   'Military',
#   'Terrorists/Non-State Militia',
#   'Military',
#   'Military',
#   'Government (General)',
#   'Educational Institution',
#   'Business',
#   'Government (Diplomatic)',
#   'Telecommunication',
#   'Government (General)',
#   'Airports & Aircraft',
#   'Government (General)',
#   'Educational Institution',
#   'Police',
#   'Educational Institution',
#   'Journalists & Media',
#   'Business',
#   'Airports & Aircraft',
#   'Business',
#   'Police',
#   'Government (General)',
#   'Police',
#   'Educational Institution',
#   'Educational Institution',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Government (Diplomatic)',
#   'Police',
#   'Religious Figures/Institutions',
#   'Police',
#   'Educational Institution',
#   'Business',
#   'Police',
#   'Government (General)',
#   'Business',
#   'Private Citizens & Property',
#   'Military',
#   'Airports & Aircraft',
#   'Government (General)',
#   'Police',
#   'Military',
#   'Military',
#   'Police',
#   'Military',
#   'Unknown',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Journalists & Media',
#   'Military',
#   'Private Citizens & Property',
#   'Military',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Religious Figures/Institutions',
#   'Business',
#   'Military',
#   'Private Citizens & Property',
#   'Military',
#   'Airports & Aircraft',
#   'Government (General)',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Police',
#   'Police',
#   'Private Citizens & Property',
#   'Police',
#   'Government (General)',
#   'Government (General)',
#   'Military',
#   'Government (Diplomatic)',
#   'Business',
#   'Government (General)',
#   'Private Citizens & Property',
#   'Government (Diplomatic)',
#   'Unknown',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Airports & Aircraft',
#   'Tourists',
#   'Educational Institution',
#   'Military',
#   'Business',
#   'Military',
#   'Business',
#   'Government (Diplomatic)',
#   'Business',
#   'Business',
#   'Educational Institution',
#   'Government (Diplomatic)',
#   'Educational Institution',
#   'Business',
#   'Business',
#   'Business',
#   'NGO',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Journalists & Media',
#   'Government (General)',
#   'Business',
#   'Government (General)',
#   'Military',
#   'Private Citizens & Property',
#   'Military',
#   'Military',
#   'Police',
#   'Business',
#   'Telecommunication',
#   'Business',
#   'Government (General)',
#   'Private Citizens & Property',
#   'Police',
#   'Military',
#   'Military',
#   'NGO',
#   'Military',
#   'Government (Diplomatic)',
#   'Police',
#   'Government (Diplomatic)',
#   'Educational Institution',
#   'Educational Institution',
#   'Police',
#   'Business',
#   'Educational Institution',
#   'Government (General)',
#   'Police',
#   'Police',
#   'Government (General)',
#   'Military',
#   'Military',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Police',
#   'Government (General)',
#   'Private Citizens & Property',
#   'Educational Institution',
#   'Government (Diplomatic)',
#   'Military',
#   'Airports & Aircraft',
#   'Business',
#   'Police',
#   'Government (Diplomatic)',
#   'Military',
#   'Educational Institution',
#   'Educational Institution',
#   'Journalists & Media',
#   'Educational Institution',
#   'Private Citizens & Property',
#   'Educational Institution',
#   'Journalists & Media',
#   'Government (General)',
#   'Government (General)',
#   'Government (General)',
#   'Business',
#   'Government (General)',
#   'Military',
#   'Business',
#   'Military',
#   'Government (General)',
#   'Military',
#   'Educational Institution',
#   'Military',
#   'Private Citizens & Property',
#   'Military',
#   'Police',
#   'Military',
#   'Educational Institution',
#   'Private Citizens & Property',
#   'Government (Diplomatic)',
#   'Private Citizens & Property',
#   'Business',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Private Citizens & Property',
#   'Military',
#   'Military',
#   'Government (General)',
#   'Military',
#   'Military',
#   'Business',
#   'Business',
#   'Military',
#   'Business',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Military',
#   'Private Citizens & Property',
#   'Government (Diplomatic)',
#   'Police',
#   'Business',
#   'Government (Diplomatic)',
#   'Business',
#   'Police',
#   'Military',
#   'Business',
#   'Government (General)',
#   'Business',
#   'Military',
#   'Business',
#   'Business',
#   'Government (General)',
#   'Educational Institution',
#   'Government (Diplomatic)',
#   'Utilities',
#   'Business',
#   'Military',
#   'Educational Institution',
#   'Religious Figures/Institutions',
#   'Religious Figures/Institutions',
#   'Religious Figures/Institutions',
#   'Religious Figures/Institutions',
#   'Terrorists/Non-State Militia',
#   'Government (General)',
#   'Military',
#   'Police',
#   'Business',
#   'Government (General)',
#   'Government (General)',
#   'Military',
#   'Private Citizens & Property',
#   'Police',
#   'Business',
#   'Journalists & Media',
#   'Utilities',
#   'Journalists & Media',
#   'Government (General)',
#   'Government (General)',
#   'Military',
#   'Business',
#   'Military',
#   'Business',
#   'Business',
#   'Educational Institution',
#   'Business',
#   'Educational Institution',
#   'Business',
#   'Government (Diplomatic)',
#   'Private Citizens & Property',
#   'Utilities',
#   'Journalists & Media',
#   'Educational Institution',
#   'Police',
#   'Private Citizens & Property',
#   'Airports & Aircraft',
#   'Private Citizens & Property',
#   'Military',
#   'Military',
#   'Military',
#   'Police',
#   'Government (General)',
#   'Utilities',
#   'Journalists & Media',
#   'Police',
#   'Educational Institution',
#   'Business',
#   'Private Citizens & Property',
#   'Government (General)',
#   'Business',
#   'Business',
#   'Business',
#   'Government (General)',
#   'Military',
#   'Military',
#   'Business',
#   'Business',
#   'Military',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Military',
#   'Police',
#   'Government (Diplomatic)',
#   'Educational Institution',
#   'Business',
#   'Government (General)',
#   'Violent Political Party',
#   'Police',
#   'Transportation',
#   'Tourists',
#   'Business',
#   'Military',
#   'Business',
#   'Government (General)',
#   'Business',
#   'Government (General)',
#   'Educational Institution',
#   'Government (General)',
#   'Business',
#   'Utilities',
#   'Military',
#   'Military',
#   'Educational Institution',
#   'Educational Institution',
#   'Educational Institution',
#   'Business',
#   'Business',
#   'Business',
#   'Military',
#   'Business',
#   'Business',
#   'Business',
#   'Military',
#   'Military',
#   'Government (General)',
#   'Business',
#   'Journalists & Media',
#   'Business',
#   'Military',
#   'Military',
#   'Telecommunication',
#   'Business',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Business',
#   'Business',
#   'Educational Institution',
#   'Military',
#   'Educational Institution',
#   'Business',
#   'Military',
#   'Utilities',
#   'Utilities',
#   'Military',
#   'Military',
#   'Government (General)',
#   'Government (Diplomatic)',
#   'Business',
#   'Government (General)',
#   'Business',
#   'Educational Institution',
#   'Business',
#   'Government (General)',
#   'Business',
#   'Business',
#   'Business',
#   'Military',
#   'Business',
#   'Private Citizens & Property',
#   'Police',
#   'Business',
#   'Government (Diplomatic)',
#   'Military',
#   'Government (Diplomatic)',
#   'Police',
#   'Transportation',
#   'Police',
#   'Police',
#   'Police',
#   'Police',
#   'Business',
#   'Police',
#   'Journalists & Media',
#   'Military',
#   'Business',
#   'Business',
#   'Utilities',
#   'Military',
#   'Police',
#   'Government (Diplomatic)',
#   'Police',
#   'Business',
#   'Telecommunication',
#   'Business',
#   'Utilities',
#   'Business',
#   'Business',
#   'Maritime',
#   'Journalists & Media',
#   'Journalists & Media',
#   'Government (General)',
#   'Tourists',
#   'Journalists & Media',
#   'Government (Diplomatic)',
#   'Government (General)',
#   'Journalists & Media',
#   'Business',
#   'Government (General)',
#   'Government (Diplomatic)',
#   'Educational Institution',
#   'Educational Institution',
#   'Business',
#   'Educational Institution',
#   'Government (General)',
#   'Business',
#   'Business',
#   'Business',
#   'Military',
#   'Business',
#   'Government (General)',
#   'Educational Institution',
#   'Business',
#   'Government (General)',
#   'Government (General)',
#   'Government (General)',
#   'Military',
#   'Military',
#   'Private Citizens & Property',
#   'Transportation',
#   'Utilities',
#   'Business',
#   'Business',
#   'Military',
#   'Government (Diplomatic)',
#   'Business',
#   'Military',
#   'Business',
#   'Business',
#   'Business',
#   'Military',
#   'Business',
#   'Military',
#   'Military',
#   'Business',
#   'Private Citizens & Property',
#   'Private Citizens & Property',
#   'Business',
#   'Military',
#   'Police',
#   'Business',
#   'Utilities',
#   'Violent Political Party',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Business',
#   'Educational Institution',
#   'Business',
#   'Airports & Aircraft',
#   'Government (General)',
#   'Airports & Aircraft',
#   'Military',
#   'Business',
#   'Business',
#   'Police',
#   'Airports & Aircraft',
#   'Police',
#   'Government (General)',
#   'Government (General)',
#   'Police',
#   'Business',
#   'Business',
#   'Military',
#   'Military',
#   'Transportation',
#   'Government (Diplomatic)',
#   'Government (Diplomatic)',
#   'Educational Institution',
#   'Educational Institution',
#   ...],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   'To protest the Cairo Illinois Police Deparment',
#   '',
#   '',
#   'To protest the War in Vietnam and the draft',
#   'To protest the War in Vietnam and the draft',
#   '',
#   'Protest the draft and Vietnam War',
#   '',
#   '',
#   'To protest United States owned businesses in Puerto Rico',
#   '',
#   '',
#   'Suspected motives were to protest the Vietnam War and/or show support for the Black Panther Party and/or show support for the Young Lords.',
#   '',
#   'Retaliation for the store owner who shot and killed an African American attempting to commit a robbery at his store.',
#   '',
#   '',
#   'The incident took place during disturbances between the Black Student Union and the university.',
#   'The incident took place during heightened antiwar sentiments in Seattle Washington.',
#   'Intimidate the Black Panther Party.',
#   '',
#   '',
#   '',
#   'The attack occurred during the violent Iowa Beef Packers strike in South Sioux City.',
#   'The motive of the attack was to prevent the African American community of West Point Mississippi from organizing.',
#   'To kill police',
#   'African American opposition to the school integration plan instituted by the federal government.  The government plan closed two Black schools.',
#   'To kill police',
#   'Protest and sabotage the draft',
#   '',
#   '',
#   'The attack occurred during the violent Iowa Beef Packers strike in South Sioux City.',
#   'The attack occurred during the violent Iowa Beef Packers strike in South Sioux City.',
#   'To protest the R.O.T.C. program and the War in Vietnam',
#   '',
#   '',
#   'Protest and sabotage the draft',
#   'To protest police presence in Pyramid Courts',
#   '',
#   '',
#   '',
#   'The attack occurred during the violent Iowa Beef Packers strike.',
#   'Sabotage/protest the integration of Denver City Schools.',
#   'To intimidate/show dissatisfaction with White sympathizers of the African American cause.',
#   '',
#   'To fight imperialism and exploitation.',
#   'To fight imperialism and exploitation.',
#   'To fight imperialism and exploitation.',
#   'To protest the R.O.T.C. program',
#   '',
#   'To fight imperialism and exploitation.',
#   'To fight imperialism and exploitation.',
#   'To fight imperialism and exploitation.',
#   'Protest employees of General Electric who were not union members',
#   '',
#   '',
#   '',
#   '',
#   'To intimidate the police.',
#   '',
#   "To protest the University of Oregon's decision to retain the R.O.T.C. program",
#   '',
#   '',
#   '',
#   'To intimidate the police.',
#   '',
#   '',
#   'Suspected motive was to protest school integration.',
#   'Protest the War in Vietnam',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Protest Vietnam War and show support for Black Panthers.',
#   'Protest anti-integrationists of the Denver City Schools.',
#   'To intimidate the African American community at Cornell University',
#   'To sabotage the Badger Ammunition Plant',
#   'The attack occurred during the violent Iowa Beef Packers strike in South Sioux City.',
#   'The attack occurred during the violent Iowa Beef Packers strike in South Sioux City.',
#   'The attack occurred during the violent Iowa Beef Packers strike in South Sioux City.',
#   'The attack occurred during the violent Iowa Beef Packers strike in South Sioux City.',
#   'Protest the draft.',
#   'Protest the desegregation of Denver City Schools.',
#   'Protest secret government research at the University of Illinois and the R.O.T.C. program.',
#   'Protesting scholarship money that was set aside for minorities but had yet to be awarded',
#   '',
#   '',
#   '',
#   'Protest the Vietnam War and the R.O.T.C.',
#   'Protest the War in Vietnam and sabotage the draft',
#   '',
#   '',
#   "To protest Frank Schaeffer's defense of the Cleveland Police Deparment during the 1968 Glenville racial riots",
#   '',
#   '',
#   '',
#   'Sabotage the US Army war efforts and protest the Vietnam War',
#   '',
#   '',
#   '',
#   '',
#   'To protest United States presence in Puerto Rico and revenge the death of Antonia Martinez Lagares',
#   '',
#   'To kill police',
#   'To kill police',
#   '',
#   '',
#   '',
#   'Protest the R.O.T.C. program and Vietnam War',
#   'The suspected motive was to disrupt the trial of H. Rap Brown',
#   '',
#   'To disrupt the trial of H. Rap Brown',
#   'To protest the policies of S. I. Hayakawa towards student demonstrators',
#   '',
#   "Protest the government's presence on the University of Illinois campus.",
#   '',
#   '',
#   '',
#   '',
#   'Protest the Vietnam War and companies profiting from the war',
#   'Protest the R.O.T.C. program and Vietnam War',
#   '',
#   '',
#   '',
#   'Protest the Vietnam War and sabotage the US Army',
#   'To impede the US war effort and protest the Vietnam War',
#   '',
#   '',
#   'To protest African Americans sitting on the San Bernardino city council',
#   'To protest the poor quality of education at a school district made up primarily of Mexican-Americans.',
#   '',
#   'Protest the Vietnam War and sabotage the US Army',
#   'To protest the civil rights movement',
#   'To protest against the draft.',
#   'Promote Puerto Rican Independence',
#   'Promote Puerto Rican Independence',
#   'Revolutionary movement against the financial establishment',
#   'Revolutionary movement against the financial establishment',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Suspected motive was to protest the Vietnam War.',
#   '',
#   '',
#   '',
#   '',
#   'Protest and sabotage the draft',
#   'To protest the trial of Lt. William Calley and show sympathy for the defendant',
#   '',
#   '',
#   'To protest against the draft.',
#   '',
#   '',
#   'Protest racism and promote a leftist revolution',
#   'To intimidate the African American community at Cornell University',
#   'Protest the Vietnam War and the R.O.T.C.',
#   '',
#   'Revolutionary movement against the financial establishment',
#   '',
#   'Revolutionary movement against the financial establishment',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Protest the strike',
#   'To protest the poor quality of education at a school district made up primarily of Mexican-Americans.',
#   'Protest non-local companies from working in East St. Louis',
#   'Protest the Vietnam War',
#   'To destabilize Cornell University',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "Intimidate pro-Castro sympathizers and protest Fidel Castro's government.",
#   'To protest the poor quality of education at a school district made up primarily of Mexican-Americans.',
#   'To protest the poor quality of education at a school district made up primarily of Mexican-Americans.',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   'To intimidate/show dissatisfaction with White sympathizers of the African American cause.',
#   'To intimidate/show dissatisfaction with White sympathizers of the African American cause.',
#   'To intimidate/show dissatisfaction with White sympathizers of the African American cause.',
#   'To intimidate/show dissatisfaction with White sympathizers of the African American cause.',
#   'To coerce the government to free the Panther 21 from prison.',
#   'This attack occurred during heightened racial tensions in Lawrence Kansas.',
#   '',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To cripple the telecommunications facilities of Puerto Rico',
#   'To cripple the telecommunications facilities of Puerto Rico',
#   'To cripple the telecommunications facilities of Puerto Rico',
#   'To cripple the telecommunications facilities of Puerto Rico',
#   'Protest the presence of the R.O.T.C. at Stanford University.',
#   'To kill police',
#   'Protest the Vietnam War and US military',
#   "Peter Huang Wen-hsiung Taiwan, a  member of WUFI, a pro-independence group, was opposed to the political views of the KMT, Chiang's party,  who favored the re-unification of Taiwan with mainland China.",
#   '',
#   "Protest the University of Pennsylvania's policies towards minorities",
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To sabotage the draft',
#   '',
#   'Protest the refusal of Yale Law School to cancel classes on May Day.',
#   'Protest military research conducted at Northwestern University.',
#   '',
#   'Protest the establishment in Ames Iowa.',
#   'Protest "river-saving" legislation in St. Charles Missouri.',
#   '',
#   '',
#   '',
#   '',
#   'To scare White Catholic residents of the Dorchester out of the area',
#   '',
#   'Protest the draft and Vietnam War',
#   'Protest the R.O.T.C. program',
#   '',
#   '',
#   '',
#   'Protest the treatment of African Americans in Champaign Illinois',
#   'Protest the treatment of African Americans in Champaign Illinois',
#   '',
#   'Protest barbershop owners who were not part of the union',
#   'Protest the R.O.T.C. program',
#   'Protest the draft',
#   'Protest the National Guard and the US military',
#   '',
#   'Protest the Vietnam War and the National Guard',
#   '',
#   'Protest the United States government',
#   '',
#   'Protest and sabotage the draft',
#   'Protest the National Guard and the US military',
#   'Protest the National Guard and the US military',
#   'Protest the policies of the US government',
#   'Protest the National Guard and the US military',
#   'Protest and sabotage the draft',
#   'To scare Jewish residents of the Dorchester out of the area',
#   '',
#   'Protest the National Guard and the US military',
#   'To force Long Island University to close',
#   'Protest and sabotage the draft',
#   'To punish Sacramento Police officers for their treatment of African Americans',
#   '',
#   '',
#   '',
#   'Intimidating/preventing KFPT from allowing Communists a network to share their views.',
#   'Protest and sabotage the draft',
#   'To kill police officers',
#   'Protest the National Guard and the US military',
#   'To protest and intimidate the White community of Oxford North Carolina',
#   '',
#   'Protest the National Guard and the US military',
#   'Protest the administration of Columbia University and the Vietnam War',
#   '',
#   'To protest and intimidate the White community of Oxford North Carolina',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Protest and sabotage the draft',
#   '',
#   'Protest and sabotage the draft',
#   'To protest the dilapidated conditions of the school, the busing of the students, and the fact that facility was closed by the School Board.',
#   '',
#   '',
#   'To kill police indiscriminately',
#   'To kill police officers',
#   'To protest the White establishment in Oxford North Carolina and economically damage White owned businesses',
#   'To protest the White establishment in Oxford North Carolina and economically damage White owned businesses',
#   'To protest the White establishment in Oxford North Carolina and economically damage White owned businesses',
#   'Protest and sabotage the draft',
#   'To scare Jewish residents of the Dorchester out of the area',
#   'To scare Jewish residents of the Dorchester out of the area',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To prevent soldiers from being deployed to fight in the Vietnam War',
#   '',
#   '',
#   '',
#   '',
#   "Protest William G. Barr 's position on mental health legislation",
#   'Protest and sabotage the draft',
#   'To attack the establishment',
#   'To protest the R.O.T.C. program and the War in Vietnam',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To attack the establishment',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Protest and sabotage the draft',
#   'To protest Black supporters of Hugh Addonizio in the 1970 Newark mayoral campaign',
#   '',
#   '',
#   '',
#   'To kill police',
#   '',
#   '',
#   'African American opposition to the police',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'African American opposition to the police',
#   'To kill police',
#   'To kill police',
#   '',
#   'To protest the Vietnam War and the draft',
#   '',
#   'To protest African Americans from moving into  a white neighborhood in Longview Texas',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To spark community wide turmoil',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To scare White Catholic residents of the Dorchester out of the area',
#   '',
#   'To protest the policies of the Organization of American States',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest Blacks supporting the establishment.',
#   '',
#   '',
#   '',
#   '',
#   'To protest the Vietnam War',
#   'To prevent the busing of African American students to the desegregated school in the Longview School District',
#   'To protest the reporting of the Akron Beacon Journal',
#   '',
#   'To protest non-participants in the San Rafael Independent Journal strike',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest individuals not participating in the strike of the San Rafael Independent Journal',
#   '',
#   'To protest and sabotage the draft',
#   '',
#   '',
#   'Intimidate the African American community of New Bedford Massachusetts.',
#   '',
#   'Protesting the multiple housing discrimination lawsuits that the Tri-Cities Human Relations Council was involved with.',
#   'Protest the draft and the US military',
#   '',
#   'Protest the draft and the US military',
#   'To protest and sabotage the draft',
#   'To kill police',
#   '',
#   "To protest the Jewish agency's operations in a predominantly Black community.",
#   '',
#   '',
#   'Protest the War in Vietnam',
#   '',
#   '',
#   '',
#   'Protest the draft and the US military',
#   '',
#   '',
#   '',
#   'Revenge for the firebombing of a Jewish Community Center in Brooklyn',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To scare the African American family into leaving neighborhood and to intimidate future African American families from moving into the neighborhood.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   '',
#   'Protest and sabotage the draft',
#   '',
#   '',
#   'Protest and sabotage the draft',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Protest and sabotage the draft and the US Army',
#   'Revenge for the firebombing of a Jewish Community Center in Brooklyn',
#   '',
#   '',
#   'Protest and sabotage the draft',
#   'To kill police',
#   '',
#   '',
#   'To kill police',
#   'Protest the national guard and the US military',
#   '',
#   '',
#   'Offensive against police',
#   '',
#   '',
#   'To prevent the school from desegregating.',
#   'To protest and sabotage the National Guard',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest the R.O.T.C. program and the war in Vietnam',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Offensive against police',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "To protest the Kaleidoscope newspaper's position towards the bombing of the Army Math Research Center at the University of Wisconsin.",
#   'To protest the R.O.T.C. program and the war in Vietnam',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest an African American Congressman representing the state of Maryland',
#   '',
#   '',
#   'To have the incident blamed on African American and cause racial conflict',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Intimidating/preventing KFPT from allowing Communists a network to share their views.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police and firefighters',
#   '',
#   'To kill police',
#   '',
#   '',
#   '',
#   'To kill police and firefighters',
#   'To kill police',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   'To protest the US military',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Suspected motive was to intimidate the African American community of New Castle Pennsylvania.',
#   'To protest the R.O.T.C. program',
#   '',
#   '',
#   '',
#   'This incident, directed against the White community of Cairo, took place during a period of widespread racial disturbances',
#   'To protest the US military',
#   'To kill African Americans',
#   '',
#   '',
#   'Protest and sabotage the draft',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To injure police',
#   '',
#   'To fight the oppression of African Americans, to attack to police, and to instigate a revolution',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Promote Puerto Rican Independence',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest the R.O.T.C. program',
#   '',
#   '',
#   'Protest and sabotage the draft',
#   '',
#   'To protest and sabotage the draft',
#   'Protest the national guard and the US military',
#   '',
#   '',
#   'To protest and sabotage the US Military',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To intimidate Julius Chambers from representing causes of the civil rights movement.',
#   '',
#   'To protest the R.O.T.C. program',
#   'Protest the draft and the US military',
#   'To protest the Pomona California school system',
#   '',
#   '',
#   '',
#   '',
#   'To protest the Pomona California school system',
#   'To protest the Pomona California school system',
#   '',
#   '',
#   'To protest the Pomona California school system',
#   '',
#   '',
#   '',
#   '',
#   'To protest and sabotage the US Military',
#   'To protest and sabotage the US Military',
#   '',
#   '',
#   '',
#   '',
#   'Protest the actions of the Cuyahoga Metropolitan Housing Authority',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   '',
#   '',
#   'To protest the appointment of a White principal at a predominantly African American school',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To intimidate Julius Chambers from representing causes of the civil rights movement.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest the appointment of a White principal at a predominantly African American school',
#   '',
#   '',
#   'To protest the reporting of the Akron Beacon Journal',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest and sabotage the US Military',
#   'To protest the War in Vietnam and the draft',
#   '',
#   '',
#   'To protest United States establishments in Puerto Rico',
#   'To protest United States establishments in Puerto Rico',
#   'To protest United States presence in Puerto Rico',
#   'To protest United States owned businesses in Puerto Rico',
#   'To protest United States owned businesses in Puerto Rico',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To promote violence against the establishment',
#   '',
#   '',
#   'To intimidate critics of the Chicano Liberation Front.',
#   '',
#   'To protest the R.O.T.C. program',
#   '',
#   'To protest the draft and United States presence in Puerto Rico',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Two different motives suspected.  Either Black radicals punishing the Churches for not allowing expelled Black students to temporarily use their facilities for classes or White racists trying to intimidate the African American community of Texarkana Texas.',
#   'Two different motives suspected.  Either Black radicals punishing the Churches for not allowing expelled Black students to temporarily use their facilities for classes or White racists trying to intimidate the African American community of Texarkana Texas.',
#   'Two different motives suspected.  Either Black radicals punishing the Churches for not allowing expelled Black students to temporarily use their facilities for classes or White racists trying to intimidate the African American community of Texarkana Texas.',
#   'Two different motives suspected.   Either Black radicals punishing the Churches for not allowing expelled Black students to temporarily use their facilities for classes or White racists trying to intimidate the African American community of Texarkana Texas.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest and sabotage the draft',
#   '',
#   'To protest the R.O.T.C. program',
#   '',
#   'To protest the draft',
#   '',
#   '',
#   "To protest Tufts University's alleged association with the Central Intelligence Agency and Dean Gullion's policies towards the War in Vietnam",
#   '',
#   '',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest the treatment of Jews by the Soviet Union',
#   'To protest the draft',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   '',
#   '',
#   'Intimidate people who promote racial harmony',
#   'Protest and sabotage the draft',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   'To protest members of the Puerto Rican Independence movement',
#   'To protest members of the Puerto Rican Independence movement',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest United States establishments in Puerto Rico',
#   'To protest and sabotage the draft',
#   '',
#   '',
#   '',
#   '',
#   'To protest United States owned businesses in Puerto Rico',
#   'To protest and sabotage the US Military',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   'To protest and sabotage the draft',
#   '',
#   '',
#   '',
#   '',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   '',
#   'To protest and the National Guard',
#   'To protest the R.O.T.C. program',
#   '',
#   '',
#   '',
#   '',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   '',
#   'To protest the treatment of Mexican-Americans',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   '',
#   'To protest the War in Vietnam and the draft',
#   'To protest and sabotage the National Guard',
#   'To protest and sabotage the draft',
#   '',
#   '',
#   '',
#   '',
#   'To protest the War in Vietnam and the draft',
#   '',
#   "To communicate to the general public that 'political activities' are not just limited to extremist groups",
#   '',
#   '',
#   '',
#   '',
#   'Suspected motive is to protest against the Vietnam War',
#   'To protest and sabotage the draft',
#   '',
#   '',
#   '',
#   'To protest the Vietnam War',
#   'To protest the Vietnam War or to protest the treatment of Mexican-Americans',
#   'To protest the draft',
#   'To protest and sabotage the US Military',
#   '',
#   '',
#   '',
#   'To protest the treatment of Mexican-Americans',
#   '',
#   '',
#   'To protest the treatment of Mexican-Americans',
#   '',
#   '',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   'Protest and sabotage the US Army',
#   '',
#   'African American opposition to the policies of the Palm Beach County school district',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   '',
#   '',
#   "To communicate to the general public that 'political activities' are not just limited to extremist groups",
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To kill police',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To protest the complicity of the Mexican government, in the death of eight student protesters, during riots in Mexico City.',
#   'To protest the complicity of the Mexican government, in the death of eight student protesters, during riots in Mexico City.',
#   '',
#   '',
#   'To protest the complicity of the Mexican government, in the death of eight student protesters, during riots in Mexico City.',
#   'To protest the complicity of the Mexican government, in the death of eight student protesters, during riots in Mexico City.',
#   'To protest the treatment of Mexican-Americans',
#   'To protest the complicity of the Mexican government, in the death of eight student protesters, during riots in Mexico City.',
#   '',
#   '',
#   '',
#   'To protest the treatment of Mexican-Americans',
#   'To protest the treatment of Mexican-Americans',
#   '',
#   'To protest the treatment of Mexican-Americans',
#   'To protest and sabotage the draft',
#   '',
#   '',
#   '',
#   'To protest the treatment of Mexican-Americans',
#   '',
#   '',
#   'To protest the treatment of Mexican-Americans',
#   '',
#   '',
#   '',
#   'To protest and sabotage the draft',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   'The Black Liberation Army stole money in order to support their armed struggle.  BLA members believed that armed struggle was the only means by which the Black Nationalist movement could break the psychological-class chains of 20th century enslavement.',
#   'To protest and the National Guard',
#   '',
#   '',
#   '',
#   'Bank of America was perceived to symbolize the "capitalist exploitation of the little man."',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Response to the death of George Jackson',
#   'Response to the death of George Jackson',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'To prevent school desegregation.',
#   '',
#   '',
#   'To protest/prevent school integration.',
#   'To protest/prevent school integration.',
#   ...],
#  ['Julio Guzman',
#   'Nadine Chaval, daughter',
#   'Employee',
#   'U.S. Embassy',
#   'U.S. Consulate',
#   'Cairo Police Headquarters',
#   'Juan Maria de Lucah/Chief of Directorate of info. and intell.',
#   'Edes Substation',
#   'R.O.T.C. offices at University of Wisconsin, Madison',
#   'Selective Service Headquarters in Madison Wisconsin',
#   'Badger Army ammo depot.',
#   'Army Recruiting Station, Denver Colorado',
#   'Flight 802 Boeing 707',
#   'Packard Properties building of Detroit Michigan',
#   "Baker's Store",
#   'Jurists Ball (Palais au Frankturm)',
#   'Soldier',
#   'James Madison High School',
#   'General Electric factory in Rio Grande Puerto Rico',
#   "Fuson's Department Store, Seattle Washington",
#   'Champaign Police Department',
#   'Secondary School, Chemistry Lab',
#   'Liberal Arts and Garrand buildings, Seattle University',
#   'Air Force R.O.T.C. at the University of Washington',
#   'Headquarters',
#   'Bodyguard, British Consul',
#   'JUSMAG HQ',
#   'Leon Jacobo Taurel, son',
#   '',
#   'Building used as a meeting place for African Americans.',
#   'New York Police Officers responding to a call in Harlem',
#   'Clay County Courthouse',
#   'New York Police Officer on patrol in Forest Hills',
#   'Selective Service office in Norwalk Ohio',
#   'Residence of President of Penal Office',
#   'Temple De Hirsch',
#   '',
#   'A & B Boat Shop',
#   'Army R.O.T.C., University of Miami',
#   'Seaman',
#   'Police Band Building, Denver Colorado',
#   'Selective Service office Local Board No. 28 in Portland Oregon',
#   'Illinois State Police in the Pyramid Courts housing project',
#   'Mays Department Store in Manhattan',
#   "Alexander's Department Store in the Bronx",
#   "Alexander's Department Store in Manhattan",
#   '',
#   'Denver City School Buses',
#   'Fred Dore',
#   '',
#   'Selective Service office in Dorado Puerto Rico',
#   '',
#   'San Juan Hotel',
#   'R.O.T.C. office, Boston University',
#   'Old Mail Hall, Wisconsin State College',
#   'Queens General Electric Service Center',
#   'Brooklyn General Electric Service Center',
#   'General Electric Headquarters',
#   'Leslie Jewel',
#   'El Al Passenger Bus & Airport Lounge',
#   '',
#   'Police parking lot',
#   "Jewish Old People's Home",
#   'Berkeley Police Station',
#   'Chase Manhattan Bank, East Village Branch',
#   'R.O.T.C. storage area, University of Oregon',
#   'police station',
#   'department store',
#   'department store',
#   'San Francisco Police Officers',
#   'Walter Boysen Paint Company',
#   'Power supply of the Frederick Maryland area',
#   'Covington High School',
#   'Armory, University of Washington',
#   '',
#   '',
#   'United States District Court of Connecticut',
#   'Columbia University International Law Library',
# ...
#   '4/25/1971: In a series of related incidents, unknown perpetrators threw a Molotov cocktail into Sumner Hall at Pomona College in Claremont, California, United States.  The firebomb caused only slight damage to the building.',
#   "4/26/1971: Unknown perpetrators firebombed the President's office of Harvey Mudd College in Claremont, California, United.  There were no casualties and it not known if the office was damaged in the incident.",
#   "4/27/1971: A bomb detonated in a men's restroom at Tamalpais High School in Mill Valley, California, United States. There were no casualties but the restroom was damaged. Two days after the bombing, Bruce Paul Lohmann, a student at the school, was arrested and admitted carrying out this attack as well as two other recent bombings at banks in the area.",
#   "4/27/1971: Unknown perpetrators bombed Julien's Furniture Store in Los Angeles, California, United States.  There were no casualties but the store was damaged.",
#   '4/28/1971: Unknown perpetrators detonated a pipe bomb outside of the Bank of America branch at the Kaiser Center in Oakland, California, United States.  There were no casualties but the building sustained an estimated $8,500 in damages.',
#   '4/28/1971: Suspected members of the Chicano Liberation Front bombed a Lincoln Heights Bank of America branch in Los Angeles, California, United States.  There were no casualties but the bank was damaged.',
#   '',
#   '4/29/1971: In a series of two incidents that might have been part of a multiple attack, suspected members of the Chicano Liberation Front bombed a Safeway in Los Angeles, California, United States.  There were no casualties but a hole was torn into the roof of the building.',
#   '4/29/1971: In a series of two incidents that might have been part of a multiple attack, suspected members of the Chicano Liberation Front bombed a Bank of America branch in Los Angeles, California, United States.  There were no casualties but the building sustained $1,600 in damages.',
#   '4/29/1971: Suspected revolutionary leftists set fire to ten trucks belonging to the Pacific Gas and Electric Company in Los Gatos, California, United States.  All ten trucks were destroyed.',
#   '4/29/1971: Christopher Brian Cowsar went to the Air Force Recruiting Station in Berkeley, California, United States and stabbed Air Force Sergeant Rogers S. Mobley to death.  During the incident Cowsar screamed, "he\'s sending people to Vietnam.  He\'s got to die."',
#   '4/30/1971: Unknown perpetrators broke into the National Guard Armory in San Jose, California, United States and set fire to trucks stationed in the parking lot.  Three vehicles were destroyed, three vehicles were heavily damaged, and one trailer was slightly damaged.  Total losses were estimated at $20,000.',
#   '4/30/1971: Unknown perpetrators failed in their attempts to bomb the Selective Service office in Braintree, Massachusetts, United States.',
#   '',
#   '',
#   '',
#   '',
#   '5/4/1971: Unknown perpetrators attempted to firebomb an Air Force Recruiting Station in Chico, California, United States.  However, the bomb fizzled out before it was able to ignite.',
#   '5/4/1971: Unknown perpetrators bombed the transmission towers of the KMAK radio station in Fresno, California, United States.  A junction box was damaged and the station was temporarily knocked off the air.',
#   '5/4/1971: Two radical leftists failed in their attempts to firebomb a Bank of America branch in San Bruno, California, United States.',
#   '',
#   '',
#   '',
#   '5/5/1971: Unknown perpetrators threw a firebomb at the American Opinion Bookstore in Chico, California, United States.  The firebomb failed to break through the window of the store but scorched the outside wall of the building.',
#   '5/5/1971: Unknown perpetrators threw three firebombs into the Old Main building at Arizona State University in Tempe, United States.  The fires were extinguished before any damage was inflicted on the building.',
#   '5/5/1971: Unknown perpetrators firebombed a Selective Service office that was located in a Federal building in Kansas City, Kansas, United States.  There were no casualties and it is not known if the building sustained any damages.',
#   '5/5/1971: Unknown perpetrators placed a pipe bomb on a street in the vicinity the campus of the University of California, Riverside, United States.  The bomb was discovered and subsequently removed.',
#   '',
#   '',
#   '5/6/1971: Unknown perpetrators bombed an unmanned Pacific Gas & Electric Company substation in the vicinity of San Jose, California, United States.  A power generator was knocked out and electric service was temporarily stopped to Los Altos, Lost Gatos, Davenport, and Big Basin.',
#   '5/6/1971: Suspected members of the Chicano Liberation Front bombed a Standard Oil refinery in East Los Angeles, California, United States.  Standard Oil was the target of anti-war demonstrators later that day.  There were no casualties but the attack caused an estimated $5,000 in damages.',
#   '5/6/1971: Unknown perpetrators firebombed a Military Recruiting Center in Burlingame, California, United States.  It is unknown if the recruiting center sustained any damages.',
#   '5/6/1971: An explosive device detonated within the vicinity of Military Trucks at the Naval Ammunition Depot in Hawthorne, Nevada, United States.  Private Charles Henderson was killed and Lance Corporal Charles Bauer was injured.',
#   '',
#   '',
#   '',
#   '5/8/1971: Suspected members of the Chicano Liberation Front bombed the Los Angeles County welfare office located in the Department of Public Social Services Building in Los Angeles, California, United States.  The were no casualties but the front door was destroyed.',
#   '',
#   '',
#   '5/9/1971: Suspected members of the Chicano Liberation Front tossed a firebomb into the Shopping Bag market in Altadena, California, United States.  There were no casualties but the supermarket sustained an estimated $2,500 in damages.',
#   '',
#   '',
#   '5/11/1971: In a series of two incidents that might have been part of a multiple attack, suspected members of the Chicano Liberation Front firebombed the Bank of America Woodland Hills branch in Los Angeles, California, United States.  The bomb smashed through a window but did not cause any damage to the interior of the building.',
#   '5/11/1971: In a series of two incidents that might have been part of a multiple attack, unknown perpetrators firebombed the Bank of America Chatworth branch in Los Angeles, California, United States.  There were no casualties but the rear door of the building was damaged.',
#   '5/11/1971: Unknown perpetrators firebombed Army Reserve Jeeps stationed at the Sheridan Armory in Baltimore, Maryland, United States.  There were no casualties but three Jeeps sustained a total of $1,500 in damages.  Nine other unexploded incendiary devices were discovered at the scene.',
#   '',
#   '5/12/1971: Unknown perpetrators bombed the car of Lloyd Early, the Superintendent of Palm Beach County.  The car was stationed in the parking lot of North Shore Junior-Senior High School in West Palm Beach, Florida, United States.  The vehicle sustained minor damages. The Palm Beach County school district was the scene of intense racial conflict.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '5/19/1971: Members of the Black Liberation Army shot and wounded two police officers, Thomas P. Curry and Nicholas J. Binetti, in Manhattan, New York, United States.  The officers were guarding the home of New York District Attorney Frank Hogan when they saw a car going the wrong way down a one-way street.  When the officers caught up with the vehicle six blocks away, the perpetrators fired shots into the police car.  The radio car was riddled with bullets and the windshield was shattered.',
#   '',
#   '',
#   '5/21/1971: Two radical leftists failed in their attempts to firebomb the San Bruno Herald in San Bruno, California, United States.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "5/28/1971: Unknown perpetrators placed a bomb in the parking lot of the Bedford Park Sherriff's Station in Bedford Park, Illinois, United States.  The bomb was discovered and subsequently disarmed a half hour before it was supposed to detonate.",
#   '',
#   '5/29/1971: Black militants fired into the Police Headquarters of Cairo, Illinois, United States, injuring a police officer.  Following the shooting, police officers noticed four men armed with guns across the street from the station.  The officers fired on the assailants initiating a shoot-out that lasted two hours.  Two additional policemen sustained bullet wounds while all four perpetrators eventually escaped.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '6/11/1971: In a series of related incidents, unknown perpetrators, protesting the actions of the Mexican government, bombed the Mexican-American radio station KALI in Los Angeles, California, United States.  There were no casualties but windows at the building were shattered.',
#   '6/11/1971: In a series of related incidents, unknown perpetrators, protesting the actions of the Mexican government, bombed the Mexican-American radio station KWKW in Pasadena, California, United States.  There were no casualties but the building sustained an estimated $1,000 in damages.  Additionally, station was knocked off the air for ten minutes.',
#   '',
#   '',
#   '6/13/1971: Unknown perpetrators, protesting the actions of the Mexican government, bombed a gas station adjacent to the Spanish language television channel KMEX-TV in Los Angeles, California, United States.  There were no casualties but a truck sustained minor damage and one window at the gas station was shattered.',
#   '6/15/1971: Unknown perpetrators, protesting the actions of the Mexican government, bombed the Joaquin Murieta Center, a Mexican-American  college recruitment facility, in Los Angeles, California, United States.  There were no casualties and it is unknown if the buildings sustained any damage.',
#   '6/16/1971: Unknown perpetrators placed a pipe bomb at the county building in Santa Cruz, California, United States.  An anonymous caller notified the authorities of the device and it was subsequently removed.',
#   '6/17/1971: Unknown perpetrators, protesting the actions of the Mexican government, bombed the Mexican-American newspaper LA Opinion in Los Angeles, California, United States.  There were no casualties but the front of the office was damaged and windows at an store adjacent store were shattered.',
#   '',
#   '6/21/1971: Unknown perpetrators placed a pipe bomb in a purse and left the device at a City Council meeting in San Jose, California, United States.  The bomb was discovered and subsequently removed.  The meeting discussed a controversial debate on a proposed mobile home development.',
#   '',
#   '6/22/1971: In a series of two incidents that might have been part of a multiple attack, suspected members of the Chicano Liberation Front bombed a campus security police car parked outside of the administration building at California State University, Los Angeles, United States.  There were no casualties but the vehicle was destroyed.',
#   "6/22/1971: In a series of two incidents that might have been part of a multiple attack, suspected members of the Chicano Liberation Front bombed a counselor's office at Lincoln High School in Los Angeles, California, United States.  While police were investigating the incident, a police car located outside of the high school was bombed.  There were no casualties but the counselor's office and the police car were both damaged.",
#   '',
#   '6/24/1971: Suspected members of the Chicano Liberation Front detonated a bomb at Belvedere Junior High School in Los Angeles, California, United States.  There were no casualties but the explosion destroyed one office at the school and shattered windows in three others.',
#   '6/25/1971: Unknown perpetrators failed in their attempts to firebomb a draft board in Freeport, New York, United States.',
#   '',
#   '',
#   '',
#   '7/1/1971: A member of the Chicano Liberation Front bombed the 63rd Army Reserve center in Los Angeles, California, United States.  There were no casualties but the building sustained an estimated $2,400 in damages.',
#   '',
#   '',
#   '7/6/1971: The Chicano Liberation Front threw a firebomb into Montebello High School in Montebello, California, United States.  There were no casualties but one classroom was destroyed and classrooms were damaged.',
#   '',
#   '7/8/1971: The Chicano Liberation Front bombed a post office in East Los Angeles, California, United States.  There were no casualties but windows were shattered.',
#   '7/9/1971: Unknown perpetrators bombed the City Hall of Providence, Rhode Island, United States.  There were no casualties but windows were shattered at the City Hall and surrounding buildings.',
#   '7/9/1971: Unknown perpetrators bombed the Selective Service Headquarters in San Diego, California, United States.  There were no casualties and it is not known if the building was damaged.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '7/18/1971: Suspected members of the Chicano Liberation Front bombed a Monterey Park branch of the Bank of America in Los Angeles, California, United States.  There were no casualties but the explosion caused extensive damage to the interior of the building.',
#   '7/21/1971: Three members of the Black Liberation Army robbed Fidelity Savings and Loan in San Francisco, California, United States.  $9,400 was stolen.',
#   "7/24/1971: Unknown perpetrators bombed and robbed the National Guard Armory in Santa Cruz, California, United States.  There were no casualties but the pipe bomb caused major damage to the armory's radio equipment room.  Several guns were also stolen.",
#   '',
#   '',
#   '',
#   '7/28/1971: Unknown perpetrators threw two firebombs into the Bank of America branch in Ben Lomond, California, United States.  The fire was extinguished quickly and caused little damage.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '8/23/1971: Unknown perpetrators placed a pipe bomb in the main lobby of Yeshiva University in Manhattan, New York, United States.  The bomb was discovered and disarmed three minutes before it was set to detonate.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '8/28/1971: In a series of related attacks, the Weathermen bombed the headquarters of the Department of Corrections Office located in a state office facility in Sacramento, California, United States.  There were no casualties but two restrooms were destroyed and the building sustained structural damage.  The incident took place on the same day as the funeral of George Jackson.',
#   '8/28/1971: Unknown perpetrators bombed the State Department of Rehabilitation Office in San Mateo California.  There were no casualties but the building sustained an estimated $40,000 in damages.  The incident took place on the same day as the funeral of George Jackson, a leader of the Black Panthers.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '8/30/1971: Ten school buses, that would have been used to transport African American students as part of a court-ordered integration plan, were blown up in Pontiac, Michigan, United States.  Five members of the Ku Klux Klan were convicted of the attack.',
#   '',
#   '',
#   '9/1/1971: Unknown perpetrators detonated a dynamite bomb in two vacant classrooms of a desegregated school in Columbus, Georgia, United States.  There were no casualties.',
#   '9/2/1971: Unknown perpetrators threw eight firebombs into the recently desegregated George Washington Carver Elementary School in Kannapolis, North Carolina, United States.  There were no casualties and the school sustained only minor damages.',
#   ...])
